# %%
import torch

np_array = torch.tensor([[1,2], [5,3]])

# %%
# 1、reshap，可针对非连续张量与连续张量改变形状
torch.reshape()

# %%
# 2、view，只能针对连续张量改变形状

# %%
# 3、transpose交换两个维度，矩阵相乘时，第一个矩阵的行一定要和另一个列匹配上，此时就需要使用到转置

# %%
# 4\squeeze/ unsquessze,增加或删除维度

# %%
# 5、连续张量：
# 连续张量：张量元素在内存中按索引顺序连续存储。连续张量可使用view 做reshap
# 非连续张量： 张量元素在内存中不是按索引顺序存储，通过转置的方式将连续张量变为非连续张量

# %%
# 6、reshap与view的区别：reshap不强控张量中元素顺序，view需要张量中元素为连续的

# %%
# 若非要使用view做性转变换， 先转为连续张量，在使用view。contiguous
