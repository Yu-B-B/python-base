# %% [markdown]
# # Step1 导入相关模块

# %%
# md 文档编辑好后esc - m - shift enter

from datasets import load_dataset
from transformers import AutoTokenizer, AutoModelForCausalLM,DataCollatorForSeq2Seq, TrainingArguments,Trainer
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 4
#       1 # md 文档编辑好后esc - m - shift enter
#       3 from datasets import load_dataset
# ----> 4 from transformers import AutoTokenizer, AutoModelForCausalLM,DataCollatorForSeq2Seq, TrainingArguments,Trainer
#
# ModuleNotFoundError: No module named 'transformers'

# %%
import datasets
datasets.__version__
# Out:
# '4.8.5'

# %%
import transformers
transformers.__version__
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 import transformers
#       2 transformers.__version__
#
# ModuleNotFoundError: No module named 'transformers'

# %% [markdown]
# # Step2 加载数据集

# %%
ds = load_dataset('json', data_dir="./alpaca_data_zh/")
ds = ds['train']
ds
# Out:
#   Cell In[12], line 1
#     ds = load_dataset('json', data_dir="./alpaca_data_zh/')
#                                        ^
# SyntaxError: unterminated string literal (detected at line 1)
