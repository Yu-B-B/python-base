# %%
# additive 范围内模型微调思路
# 1、在模型中添加新的可调参数层
# 2、保持基模型参数冻结，进更新添加层的参数

'''

hard prompt: 人为在输入内容前添加指定内容后拼接为一个完成句子

soft prompt：在输入内容前添加虚拟的Token（通过学习而来：求最小化损失函数 - 反向传播 - 调节参数）；在soft prompt中为句子前实际想要添加的是连续的Token

离散prompt：人为输入

连续prompt：通过大模型自行推理得到符合当前语句的prompt，


soft prompt 在参数量足够大时，可与全量调参媲美


使用peft微调模型

import peft

from peft import PrompTuningConfig, get_peft_model, TaskType, PromptTuningInit

config = PromptTuningInit(task_type = TaskType.CAUSAL_LM, num_virtual_token=10)

创建模型

model = 

'''
